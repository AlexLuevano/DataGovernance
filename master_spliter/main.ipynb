# %%
import pandas as pd
import xlsxwriter
from tkinter import *
from tkinter import filedialog
import os
import sys



def browse_files():
    global filename
    filename = filedialog.askopenfilename(initialdir = "/Downloads", title = "Selecciona un archivo:", filetypes = (("all files","*.*"),(".xlsx Files","*.xlsx")))
    if filename:
            l1 = Label(window, text = "File path: " + filename).pack()
    else:
            print('No seleccionaste ningún archivo.')
    window.destroy()

# %%
window = Tk()
window.title("Master per APREF")
window.geometry("200x100")
label_file_explorer = Label(window, text = "Master per APREF", width = 100, height = 4).pack()
button_explore = Button(window, text = "Buscar archivo", command = browse_files).pack()
window.mainloop()

df = pd.read_excel(f'{filename}', index_col = False,na_filter= False)
#writer = pd.ExcelWriter('excel_merged.xlsx' ,engine='xlsxwriter')
aprefs = list(df['Ap Ref'].unique())

if os.path.exists('C:\\temporary'):
    print(r'File succesfully split. Please review files at C:\\temporary')
    pass
else:
    print('C:\\temporary directory does not exist. Do you want to create it? Y/N?')
    answer = input()
    if answer == 'Y' or 'y':
        os.mkdir(r'C:\\temporary')
        for num in aprefs:
            temp_df = df[df['Ap Ref'] == num]
            temp_df.to_excel(f'C:\\temporary\\{num}.xlsx',index = False, header = True)
        print(r'File succesfully split. Please review files at C:\\temporary')
    elif answer == 'N' or 'n':
        print('Ok. Finishing execution')
        sys.exit()
    else:
        print('Invalid answer. Finishing execution')
        sys.exit()
# Out:
# File succesfully split. Please review files at C:\\temporary

# %%
import pandas as pd
import xlsxwriter
from tkinter import *
from tkinter import filedialog
import os
import sys


window = Tk()

def browse_files():
    global filename
    filename = filedialog.askopenfilename(initialdir = "/Downloads", title = "Selecciona un archivo:", filetypes = (("all files","*.*"),(".xlsx Files","*.xlsx")))
    if filename:
            l1 = Label(window, text = "File path: " + filename).pack()
    else:
            print('No seleccionaste ningún archivo.')
    window.destroy()


def main():
    #window = Tk()
    window.title("Master per APREF")
    window.geometry("200x100")
    label_file_explorer = Label(window, text = "Master per APREF", width = 100, height = 4).pack()
    button_explore = Button(window, text = "Buscar archivo", command = browse_files).pack()
    window.mainloop()

    df = pd.read_excel(f'{filename}', index_col = False,na_filter= False)
    #writer = pd.ExcelWriter('excel_merged.xlsx' ,engine='xlsxwriter')
    aprefs = list(df['Ap Ref'].unique())

    if os.path.exists('C:\\temporary'):
        print(r'File succesfully split. Please review files at C:\\temporary. Finishing execution.')
        exit()
    else:
        print('C:\\temporary directory does not exist. Do you want to create it? Y/N?')
        answer = input()
        if answer == 'Y' or 'y':
            os.mkdir(r'C:\\temporary')
            for num in aprefs:
                temp_df = df[df['Ap Ref'] == num]
                temp_df.to_excel(f'C:\\temporary\\{num}.xlsx',index = False, header = True)
            print(r'File succesfully split. Please review files at C:\\temporary')
            exit()
        elif answer == 'N' or 'n':
            print('Ok. Finishing execution')
            exit()
        else:
            print('Invalid answer. Finishing execution')
            exit()

if __name__ == '__main__':
    main()
# Out:
# File succesfully split. Please review files at C:\\temporary. Finishing execution.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\aluevano\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3449: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
temp_df
# Out:
#                KEY                KEY2      Team        Category  \
# 4766  668598|16109  668598|16109|86157  UNDERCAR  EXHAUST SYSTEM
# 4767  668599|16109  668599|16109|86157  UNDERCAR  EXHAUST SYSTEM
# 4768  668601|16109  668601|16109|86157  UNDERCAR  EXHAUST SYSTEM
# 4769  668649|16109  668649|16109|86157  UNDERCAR  EXHAUST SYSTEM
# 4770  668718|16109  668718|16109|86157  UNDERCAR  EXHAUST SYSTEM
# ...            ...                 ...       ...             ...
# 4861  685079|16109  685079|16109|86157  UNDERCAR        STEERING
# 4862  702443|16109  702443|16109|86157  UNDERCAR        STEERING
# 4863  815450|16109  815450|16109|86157  UNDERCAR        STEERING
# 4864  726267|16109  726267|16109|86157  UNDERCAR        STEERING
# 4865  813826|16109  813826|16109|86157  UNDERCAR        STEERING
#
#         Sub Category Category Manager     SKU    Part Number  Line Code  \
# 4766  EXHAUST REPAIR    STEVEN THOMAS  668598     1269970041        589
# 4767  EXHAUST REPAIR    STEVEN THOMAS  668599     1269970141        589
# 4768  EXHAUST REPAIR    STEVEN THOMAS  668601         147581         40
# 4769  EXHAUST REPAIR    STEVEN THOMAS  668649     2104900440        589
# 4770  EXHAUST REPAIR    STEVEN THOMAS  668718    11621304755        589
# ...              ...              ...     ...            ...        ...
# 4861   MISC STEERING    STEVEN THOMAS  685079     1294600019        738
# 4862   MISC STEERING    STEVEN THOMAS  702443  1154600510URO        738
# 4863   MISC STEERING    STEVEN THOMAS  815450    56483RDAA01          1
# 4864           RACKS    STEVEN THOMAS  726267   32136751026E        738
# 4865  STEERING PUMPS    STEVEN THOMAS  813826         348424        405
#
#      Alt Part Number  ... Check with Category Manager SKU in MDM  \
# 4766                  ...                                      Y
# 4767                  ...          Max per Car > 1 |           Y
# 4768                  ...          Max per Car > 1 |           Y
# 4769                  ...                                      Y
# 4770                  ...                                      Y
# ...              ...  ...                         ...        ...
# 4861                  ...                                      Y
# 4862                  ...                                      Y
# 4863                  ...                                      Y
# 4864                  ...                                      Y
# 4865                  ...                                      Y
#
#      SKU|APREF in MDM  SKU|APREF|POV in MDM                  MDM ID  Stage  \
# 4766                Y                     Y  f0Nw2124RtCa7p_TuYTG7A     1B
# 4767                Y                     Y  oWtIu9wOTrOGcaRRNXfZYw     1B
# 4768                Y                     Y  YUOT6-TRTh-wwVcwfv5ZGA     1B
# 4769                Y                     Y  o_XyivmqT1uHUJaQ1f-yLg     1B
# 4770                Y                     Y  YyFG5eLPRAKuEAcmq7IUYA     1B
# ...               ...                   ...                     ...    ...
# 4861                Y                     Y  YFyaO0EiSFCesTYAL4vVwQ     1B
# 4862                Y                     Y  RcV5ITy5QkepWQTcpUVSMw      3
# 4863                Y                     Y  fjpzDLugQue6uPJ-nmcapg     1B
# 4864                Y                     Y  sk-97xeeRRGgMuDRzk6htg     1B
# 4865                Y                     Y  y194h9hvTlmas2pvYvkggw     1B
#
#                                           Status       Stage 1B  Stage 2  \
# 4766                                              Missing SCH B
# 4767                                              Missing SCH B
# 4768                                              Missing SCH B
# 4769                                              Missing SCH B
# 4770                                              Missing SCH B
# ...                                          ...            ...      ...
# 4861                                              Missing SCH B
# 4862  DG Revision Complete Stage 2 AL 10/01/2021             Ok       Ok
# 4863                                              Missing SCH B
# 4864                                              Missing SCH B
# 4865                                              Missing SCH B
#
#       Stage 3
# 4766
# 4767
# 4768
# 4769
# 4770
# ...       ...
# 4861
# 4862
# 4863
# 4864
# 4865
#
# [100 rows x 51 columns]
